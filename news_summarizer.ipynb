# %% [markdown]
# <a href="https://colab.research.google.com/github/yashaswini-cyber/news-aggregator-summarizer/blob/main/news_summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from transformers import pipeline
import sys
import os
import time

# Debugging Information
print("Python executable being used:", sys.executable)
print("Process ID:", os.getpid())

# Replace with your actual NewsAPI key
API_KEY = '98afa421e8784abd93f1eb00510347d1'
URL = f'https://newsapi.org/v2/top-headlines?country=us&apiKey={API_KEY}'

# Fetch the news articles
try:
    print("Fetching news articles...")
    response = requests.get(URL)
    response.raise_for_status()  # Check for HTTP request errors
    news_data = response.json()
    articles = news_data.get('articles', [])
    if not articles:
        raise Exception("No articles found")
except requests.exceptions.RequestException as e:
    raise SystemExit(f"Failed to fetch news articles: {e}")

# Function to extract article content using BeautifulSoup
def get_article_content(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'
    }
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract text from paragraphs
        paragraphs = soup.find_all('p')
        article_text = ' '.join([para.get_text() for para in paragraphs])

        # Ensure article is not empty and truncate to avoid token overflow
        return article_text[:4000] if article_text else None
    except Exception as e:
        print(f"Failed to extract article content from {url}: {e}")
        return None

# Extract content for all articles
article_contents = []
for article in articles:
    print(f"Fetching article: {article['title']}")
    content = get_article_content(article['url'])
    if content:
        article_contents.append((article['title'], article['url'], content))
    time.sleep(1)  # Adding delay to avoid request rate limits

if not article_contents:
    raise Exception("No valid article contents extracted")

# Initialize the summarization pipeline
try:
    print("Initializing summarizer...")
    summarizer = pipeline('summarization', model='facebook/bart-large-cnn', device=-1)  # Use CPU
except Exception as e:
    raise SystemExit(f"Failed to initialize summarization pipeline: {e}")

# Function to summarize article content
def summarize_article(content):
    try:
        # Truncate content to 1024 tokens (BART model limitation)
        if len(content) > 1024:
            content = content[:1024]
        summary = summarizer(content, max_length=130, min_length=30, do_sample=False)
        return summary[0]['summary_text']
    except Exception as e:
        print(f"Failed to summarize article content: {e}")
        return None

# Summarize all articles
summaries = []
for title, url, content in article_contents:
    print(f"Summarizing article: {title}")
    summary = summarize_article(content)
    if summary:
        summaries.append((title, summary, url))
    else:
        print(f"Skipping article due to summarization failure: {title}")

if not summaries:
    raise Exception("No summaries generated")

# Print titles, summaries, and links
print("\n--- News Summaries ---\n")
for title, summary, url in summaries:
    print(f"Title: {title}")
    print(f"Summary: {summary}")
    print(f"Link: {url}\n")
# Out:
# Python executable being used: /usr/bin/python3
# Process ID: 3555
# Fetching news articles...
# Fetching article: Live Briefing: Gaza death toll crosses 45,000, Health Ministry says - The Washington Post
# Fetching article: Amazon Disregarded Internal Warnings on Injuries, Senate Investigation Claims - The New York Times
# Fetching article: What we learned in NFL Week 15: MVP is Josh Allen’s to lose, Packers stay hot - The Athletic - The Athletic
# Fetching article: The federal EV tax credit has an uncertain fate. What car shoppers should know - NPR
# Fetching article: Kraven the Hunter Has Worst Ever Box Office Opening Weekend for a Sony Spider-Man Universe Movie, Even Below Madame Web - IGN
# Fetching article: Memphis man convicted of killing his bride on their honeymoon in Fiji in 2022 - CBS News
# Fetching article: Seven hotel guests suffer suspected poisoning after drinking cocktails at 5-star Fiji resort - CNN
# Fetching article: Expect an Icy Commute for Parts of the Northeast on Monday Morning - The New York Times
# Fetching article: Schumer urges Biden admin to deploy "special drone-detection tech" to N.Y. and N.J. - Axios
# Failed to extract article content from https://www.axios.com/2024/12/15/drone-detection-new-york-new-jersey-chuck-schumer: 403 Client Error: Forbidden for url: https://www.axios.com/2024/12/15/drone-detection-new-york-new-jersey-chuck-schumer
# Fetching article: People starting to die of thirst and hunger in cyclone-hit Mayotte, warns French senator - BBC.com
# Fetching article: Israel will close its Ireland embassy over Gaza tensions - NPR
# Fetching article: The Fed’s Game Plan on Interest-Rate Cuts Keeps Shifting - The Wall Street Journal
# Failed to extract article content from https://www.wsj.com/economy/central-banking/fed-interest-rate-cut-outlook-2025-657e718a: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/economy/central-banking/fed-interest-rate-cut-outlook-2025-657e718a
# Fetching article: Survivors seek a reckoning as FBI investigates child sex abuse in little-known Christian sect - The Associated Press
# Fetching article: Apple TV+ Drops Surprise Holiday Edition of ‘Carpool Karaoke’ With Lady Gaga, Dua Lipa and Chappell Roan - Hollywood Reporter
# Fetching article: NFL Week 15 grades: Josh Allen leads Bills to 'A' in win vs. Lions, Eagles get high grade for beating Steelers - CBS Sports
# Fetching article: 2024 Week 15 Rapid Reactions: Seahawks Lose To Packers & Lose Geno Smith To Injury - Seahawks.com
# Fetching article: Vikings clinch postseason berth with Seahawks loss to Packers - NBC Sports
# Fetching article: Asia wary of Fed rate plans, China retail disappoints By Reuters - Investing.com
# Fetching article: Could mouse sperm orbiting Earth be the future of humanity? - CNN
# Fetching article: How ‘Yellowstone’ Finale Set up Beth & Rip Spinoff and Circled Back to ‘1883’ - TV Insider
# Initializing summarizer...
# Summarizing article: The federal EV tax credit has an uncertain fate. What car shoppers should know - NPR
# Summarizing article: Kraven the Hunter Has Worst Ever Box Office Opening Weekend for a Sony Spider-Man Universe Movie, Even Below Madame Web - IGN
# Summarizing article: Memphis man convicted of killing his bride on their honeymoon in Fiji in 2022 - CBS News
# Summarizing article: Seven hotel guests suffer suspected poisoning after drinking cocktails at 5-star Fiji resort - CNN
# Summarizing article: Israel will close its Ireland embassy over Gaza tensions - NPR
# Summarizing article: NFL Week 15 grades: Josh Allen leads Bills to 'A' in win vs. Lions, Eagles get high grade for beating Steelers - CBS Sports
# Summarizing article: 2024 Week 15 Rapid Reactions: Seahawks Lose To Packers & Lose Geno Smith To Injury - Seahawks.com
# Summarizing article: Vikings clinch postseason berth with Seahawks loss to Packers - NBC Sports
# Summarizing article: Could mouse sperm orbiting Earth be the future of humanity? - CNN
# Summarizing article: How ‘Yellowstone’ Finale Set up Beth & Rip Spinoff and Circled Back to ‘1883’ - TV Insider
#
# --- News Summaries ---
#
# Title: The federal EV tax credit has an uncertain fate. What car shoppers should know - NPR
# Summary: Currently, drivers can access a federal tax credit worth up to $7,500 for buying or leasing an electric vehicle. There's a smaller credit for used EVs, too. Incoming Trump administration has declared the tax credits wasteful spending.
# Link: https://www.npr.org/2024/12/16/nx-s1-5220379/car-electric-trump-tax-credit
#
# Title: Kraven the Hunter Has Worst Ever Box Office Opening Weekend for a Sony Spider-Man Universe Movie, Even Below Madame Web - IGN
# Summary: Kraven the Hunter is the worst ever opening for a Sony Spider-Man Universe movie. The R-rated action flick comes in under the disastrous Madame Web. Kraven has $26 million globally this weekend.
# Link: https://www.ign.com/articles/kraven-the-hunter-has-worst-ever-box-office-opening-weekend-for-a-sony-spider-man-universe-movie-even-below-madame-web
#
# Title: Memphis man convicted of killing his bride on their honeymoon in Fiji in 2022 - CBS News
# Summary: Bradley Robert Dawson, 40, killed his wife, Christe Chen, who was 36, at the exclusive Turtle Island resort in Fiji. Chen was discovered in the couple's room by resort staff with multiple blunt trauma wounds to her head. Dawson had denied the charge.
# Link: https://www.cbsnews.com/news/memphis-man-bradley-dawson-convicted-killing-wife-honeymoon-fiji/
#
# Title: Seven hotel guests suffer suspected poisoning after drinking cocktails at 5-star Fiji resort - CNN
# Summary: The tourists, ages 18 to 56, suffered nausea, vomiting and “neurological symptoms,” Fiji’s Health Ministry says. Four Australians, along with three other people believed to be foreign nationals, were taken to the hospital. The case comes just weeks after six tourists died from methanol poisoning in Laos.
# Link: https://www.cnn.com/2024/12/15/world/fiji-tourists-cocktail-drinks-hospitalization-intl-hnk/index.html
#
# Title: Israel will close its Ireland embassy over Gaza tensions - NPR
# Summary: The decision to close the embassy came in response to what Israel's foreign minister has described as Ireland's "extreme anti-Israel policies" Israel recalled its ambassador to Dublin after Ireland announced, along with Norway, Spain and Slovenia, it would recognize a Palestinian state.
# Link: https://www.npr.org/2024/12/16/g-s1-38403/israel-will-close-its-ireland-embassy-over-gaza-tensions
#
# Title: NFL Week 15 grades: Josh Allen leads Bills to 'A' in win vs. Lions, Eagles get high grade for beating Steelers - CBS Sports
# Summary: The Miami Dolphins wilted under the pressure of playing in a must-win game with a 20-12 loss to the Texans. The Dolphins are now 1-11 since the start of the 2023 season against teams that are over .500. Josh Allen made an MVP statement by throwing for 362 yards and two touchdowns in a 48-42 win over the Lions.
# Link: https://www.cbssports.com/nfl/news/nfl-week-15-grades-josh-allen-leads-bills-to-a-in-win-vs-lions-eagles-get-high-grade-for-beating-steelers/
#
# Title: 2024 Week 15 Rapid Reactions: Seahawks Lose To Packers & Lose Geno Smith To Injury - Seahawks.com
# Summary: The Packers jumped out to a big early lead and never looked back on their way to a 30-13 win. The Seahawks also saw quarterback Geno Smith exit the game early with a knee injury.
# Link: https://www.seahawks.com/news/rapid-reactions-seahawks-lose-to-packers-lose-geno-smith-to-injury
#
# Title: Vikings clinch postseason berth with Seahawks loss to Packers - NBC Sports
# Summary: The Vikings entered this weekend second in the NFC North at 11-2. They now control their own outcome in the division race because Detroit fell to Buffalo. If the Vikings and Lions continue to win for the next few weeks, they’ll play for the division crown.
# Link: https://www.nbcsports.com/nfl/profootballtalk/rumor-mill/news/vikings-clinch-postseason-berth-with-seahawks-loss-to-packers
#
# Title: Could mouse sperm orbiting Earth be the future of humanity? - CNN
# Summary:  freeze-dried mouse sperm stored aboard the International Space Station in a radiation protection box. Professor Teruhiko Wakayama will study them to determine impact of the space enviro.
# Link: https://www.cnn.com/science/japan-space-ivf-mice-experiments-hnk-spc/index.html
#
# Title: How ‘Yellowstone’ Finale Set up Beth & Rip Spinoff and Circled Back to ‘1883’ - TV Insider
# Summary: Season 5 finale of Yellowstone revealed the ranch’s long-time-coming fate. Kayce (Luke Grimes) sold the entire property to Thomas Rainwater (Gil Birmingham) The two-hour finale also revealed big changes for Beth (Kelly Reilly) and Rip.
# Link: https://www.tvinsider.com/1166644/yellowstone-finale-recap-season-5-ranch-sold-jamie-dead-beth-rip-elsa-dutton-1883/
